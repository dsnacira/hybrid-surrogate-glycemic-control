# %% [markdown]
# ## Runs the optimization experiments and generates raw results.

# %%
# !pip install simglucose==0.2.11
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.8/157.8 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.6 MB/s eta 0:00:00
# ...
#   Created wheel for gym: filename=gym-0.9.4-py3-none-any.whl size=215456 sha256=5dc24fe29079f1eebf2c7aed3da1470d6dd7b396b70590bdd5224f6622507fdd
#   Stored in directory: /root/.cache/pip/wheels/f9/12/86/011b8ba7c0f38ccbb5e524459c3d57cbd35bd8df9035fcdd4f
# Successfully built gym
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

project_path = "/content/drive/MyDrive/Research/glycemic-hybrid-ga"

# Vérifier existence
print("Exists:", os.path.exists(project_path))

# Aller dans le dossier
# %cd /content/drive/MyDrive/Research/glycemic-hybrid-ga

# Vérifier contenu
# !ls

# Lancer
# !python -m src.run_experiments --save_figs
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Exists: True
# /content/drive/MyDrive/Research/glycemic-hybrid-ga
# config		      fig_trajectory_S3.pdf	 outputs
# data		      figures			 README.md
# fig_main_results.pdf  glycemic-hybrid-ga-v2.zip  requirements.gdoc
# fig_regret.pdf	      notebooks			 src
#
# === Running scenario: S1_normal ===
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/drive/MyDrive/Research/glycemic-hybrid-ga/src/run_experiments.py", line 482, in <module>
#     main()
#   File "/content/drive/MyDrive/Research/glycemic-hybrid-ga/src/run_experiments.py", line 345, in main
#     res = run_method(
#           ^^^^^^^^^^^
#   File "/content/drive/MyDrive/Research/glycemic-hybrid-ga/src/run_experiments.py", line 110, in run_method
#     return run_ga_only(
# ...
